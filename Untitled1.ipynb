# %%
import numpy as np
import pandas as pd

# %%
data = np.array([[1,2],[3,4]])

# %%
df = pd.DataFrame(data,index=["row1","row2"],columns=["col1","col2"])

# %%
df
# Out:
#       col1  col2
# row1     1     2
# row2     3     4

# %% [markdown]
# second way

# %%
data = [[1,2],[3,4]]

# %%
df = pd.DataFrame(data,index=["row1","row2"],columns=["col1","col2"])

# %%
df
# Out:
#       col1  col2
# row1     1     2
# row2     3     4

# %% [markdown]
# # real data

# %%
state = ["uk", "hp","mp"]
population = ["1.25 Crore","68 Lac", "8.95 Crores"]

# %%
data = {"State":state,"Population":population}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   State   Population
# 0    uk   1.25 Crore
# 1    hp       68 Lac
# 2    mp  8.95 Crores

# %% [markdown]
# # read csv

# %%
data = pd.read_csv("StudentsPerformance.csv")

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd

# %%
name=["asdf"]
age = [23]
data = {"name":name,"age":age}
df = pd.DataFrame(data)

# %%
df
# Out:
#    name  age
# 0  asdf   23

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
pd.set_option('display.max_rows',10)

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # Function

# %%
len(df)
# Out:
# 1000

# %%
max(df.index)
# Out:
# 999

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.reset_option('display.max_rows')

# %%
df['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df[['gender','lunch']]
# Out:
#      gender         lunch
# 0    female      standard
# 1    female      standard
# 2    female      standard
# 3      male  free/reduced
# 4      male      standard
# ..      ...           ...
# 995  female      standard
# 996    male  free/reduced
# 997  female  free/reduced
# 998  female      standard
# 999  female  free/reduced
#
# [1000 rows x 2 columns]

# %%
df['weight'] = 70

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  weight
# ...

# %%
import numpy as np

# %%
random_score = np.random.randint(1, 100, size = 1000)

# %%
max(random_score)
# Out:
# np.int32(99)

# %%
min(random_score)
# Out:
# np.int32(1)

# %%
df['weight'] = random_score

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  weight
# ...

# %%
score1 = np.random.randint(1,100,size=1000)
score2 = np.random.randint(1,100,size=1000)
series1 = pd.Series(score1, index=np.arange(0,1000))
series2 = pd.Series(score2, index=np.arange(0,1000))
series2
# Out:
# 0      16
# 1      17
# 2       7
# 3      46
# 4      45
#        ..
# 995    76
# 996    48
# 997    24
# 998    37
# 999    90
# Length: 1000, dtype: int32

# %%
df = df.assign(score1 = series1, score2 = series2)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  weight  \
# ...

# %%
df.insert(1,"testing", series2)

# %%
df
# Out:
#      gender  testing race/ethnicity parental level of education         lunch  \
# 0    female       16        group B           bachelor's degree      standard
# 1    female       17        group C                some college      standard
# 2    female        7        group B             master's degree      standard
# 3      male       46        group A          associate's degree  free/reduced
# 4      male       45        group C                some college      standard
# ..      ...      ...            ...                         ...           ...
# 995  female       76        group E             master's degree      standard
# 996    male       48        group C                 high school  free/reduced
# 997  female       24        group C                 high school  free/reduced
# 998  female       37        group D                some college      standard
# 999  female       90        group D                some college  free/reduced
#
# ...

# %% [markdown]
# # operation

# %%
df['testing'].sum()
# Out:
# np.int64(49285)

# %%
df['math score'].sum()
# Out:
# np.int64(66089)

# %%
df['math score'].count()
# Out:
# np.int64(1000)

# %%
df['math score'].mean()
# Out:
# np.float64(66.089)

# %%
df['math score'].std()
# Out:
# 15.163080096009468

# %%
df['math score'].max()
# Out:
# 100

# %%
df['math score'].min()
# Out:
# 0

# %%
df.describe()
# Out:
#            testing  math score  reading score  writing score       weight  \
# count  1000.000000  1000.00000    1000.000000    1000.000000  1000.000000
# mean     49.285000    66.08900      69.169000      68.054000    51.675000
# std      28.851277    15.16308      14.600192      15.195657    28.576389
# min       1.000000     0.00000      17.000000      10.000000     1.000000
# 25%      24.000000    57.00000      59.000000      57.750000    27.750000
# 50%      49.000000    66.00000      70.000000      69.000000    52.000000
# 75%      74.000000    77.00000      79.000000      79.000000    77.000000
# max      99.000000   100.00000     100.000000     100.000000    99.000000
#
#             score1       score2
# count  1000.000000  1000.000000
# mean     51.026000    49.285000
# std      28.848146    28.851277
# min       1.000000     1.000000
# 25%      26.000000    24.000000
# 50%      51.000000    49.000000
# 75%      77.000000    74.000000
# max      99.000000    99.000000

# %%
df['testing']+ df['score1'] + df['score2']
# Out:
# 0       68
# 1       37
# 2       32
# 3      103
# 4      148
#       ...
# 995    197
# 996    130
# 997     98
# 998    142
# 999    231
# Length: 1000, dtype: int32

# %%
df['average'] = df['testing']+ df['score1'] + df['score2']/3

# %%
df
# Out:
#      gender  testing race/ethnicity parental level of education         lunch  \
# 0    female       16        group B           bachelor's degree      standard
# 1    female       17        group C                some college      standard
# 2    female        7        group B             master's degree      standard
# 3      male       46        group A          associate's degree  free/reduced
# 4      male       45        group C                some college      standard
# ..      ...      ...            ...                         ...           ...
# 995  female       76        group E             master's degree      standard
# 996    male       48        group C                 high school  free/reduced
# 997  female       24        group C                 high school  free/reduced
# 998  female       37        group D                some college      standard
# 999  female       90        group D                some college  free/reduced
#
# ...

# %%
df['lunch'].count()
# Out:
# np.int64(1000)

# %%
df['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df['lunch'].value_counts(normalize=True)
# Out:
# lunch
# standard        0.645
# free/reduced    0.355
# Name: proportion, dtype: float64

# %%
df['math score'].value_counts()
# Out:
# math score
# 65    36
# 62    35
# 69    32
# 59    32
# 73    27
#       ..
# 24     1
# 26     1
# 19     1
# 23     1
# 8      1
# Name: count, Length: 81, dtype: int64

# %%
pd.set_option('display.max_rows',20)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# ..      ...            ...                         ...           ...
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ..                      ...         ...            ...            ...
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
df['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# parental level of education
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: proportion, dtype: float64

# %%
df.sort_values('math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 962  female        group E          associate's degree      standard
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
 df.sort_values(['gender', 'math score'], ascending=False, inplace=True)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['math score'].value_counts(normalize=True).round(2)
# Out:
# math score
# 65    0.04
# 62    0.04
# 69    0.03
# 59    0.03
# 61    0.03
#       ...
# 22    0.00
# 19    0.00
# 18    0.00
# 8     0.00
# 0     0.00
# Name: proportion, Length: 81, dtype: float64

# %%
df.sort_values('race/ethnicity', ascending=True, key=lambda x:x.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 170    male        group A                 high school      standard
# 902  female        group A                 high school  free/reduced
# 635    male        group A                 high school      standard
# 830  female        group A                some college  free/reduced
# 395    male        group A                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 616  female        group E           bachelor's degree      standard
# 802  female        group E          associate's degree      standard
# 277  female        group E                 high school      standard
# 458  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
