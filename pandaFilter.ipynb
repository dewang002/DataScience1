# %%
import pandas as pd

# %%
df = pd.read_csv('laptop price.csv', encoding='latin')

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # isin

# %%
df[df['Company'].isin(['Apple', 'Samsung'])].value_counts('Company')
# Out:
# Company
# Apple      21
# Samsung     9
# Name: count, dtype: int64

# %%
# multiple filteration
filter1= df['TypeName'].isin(['Ultrabook','Notebook'])
filter2= df['Company'].isin(['Apple','Samsung'])

# %%
df[filter1 & filter2]
# Out:
#       laptop_ID  Company           Product   TypeName  Inches  \
# 0             1    Apple       MacBook Pro  Ultrabook    13.3
# 1             2    Apple       Macbook Air  Ultrabook    13.3
# 3             4    Apple       MacBook Pro  Ultrabook    15.4
# 4             5    Apple       MacBook Pro  Ultrabook    13.3
# 6             7    Apple       MacBook Pro  Ultrabook    15.4
# 7             8    Apple       Macbook Air  Ultrabook    13.3
# 12           13    Apple       MacBook Pro  Ultrabook    15.4
# 14           15    Apple       MacBook 12"  Ultrabook    12.0
# 15           16    Apple       MacBook Pro  Ultrabook    13.3
# 17           18    Apple       MacBook Pro  Ultrabook    15.4
# 26           27    Apple       MacBook Air  Ultrabook    13.3
# 34           35    Apple       MacBook Air  Ultrabook    13.3
# 45           46    Apple       MacBook Pro  Ultrabook    13.3
# 81           83    Apple       MacBook 12"  Ultrabook    12.0
# ...

# %%
df[df['Inches'].isin([15])]
# Out:
#       laptop_ID  Company        Product            TypeName  Inches  \
# 771         780  Samsung     Notebook 9  2 in 1 Convertible    15.0
# 874         885  Samsung     Notebook 9           Ultrabook    15.0
# 892         903  Samsung     Notebook 9           Ultrabook    15.0
# 1224       1242     Dell  Inspiron 5578  2 in 1 Convertible    15.0
#
#                      ScreenResolution                         Cpu   Ram  \
# 771   Full HD / Touchscreen 1920x1080  Intel Core i7 7500U 2.7GHz  16GB
# 874                 Full HD 1920x1080  Intel Core i7 7500U 2.7GHz  16GB
# 892                 Full HD 1920x1080  Intel Core i7 7500U 2.7GHz   8GB
# 1224  Full HD / Touchscreen 1920x1080  Intel Core i3 7100U 2.4GHz   4GB
#
#          Memory                    Gpu       OpSys  Weight  Price_euros
# 771   256GB SSD         AMD Radeon 540  Windows 10  1.71kg       1799.0
# 874   256GB SSD   Nvidia GeForce 940MX  Windows 10  1.23kg       1849.0
# ...

# %% [markdown]
# # to check for dublicates

# %%
df[df.duplicated('Company')].value_counts('Company')
# Out:
# Company
# Dell         296
# Lenovo       296
# HP           273
# Asus         157
# Acer         102
# MSI           53
# Toshiba       47
# Apple         20
# Samsung        8
# Mediacom       6
# Razer          6
# Microsoft      5
# Vero           3
# Xiaomi         3
# Chuwi          2
# Fujitsu        2
# LG             2
# Google         2
# Huawei         1
# Name: count, dtype: int64

# %%
data = df.duplicated(['Price_euros'])

# %%
data
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301     True
# 1302     True
# Length: 1303, dtype: bool

# %%
df[data]
# Out:
#       laptop_ID Company                                  Product  \
# 37           38    Dell                            Inspiron 5770
# 44           45    Dell                            Inspiron 7773
# 56           57      HP  15-bs002nv (i3-6006U/4GB/128GB/FHD/W10)
# 60           61    Dell                            Inspiron 5770
# 61           62    Dell                              Vostro 5471
# ...         ...     ...                                      ...
# 1298       1316  Lenovo                           Yoga 500-14ISK
# 1299       1317  Lenovo                           Yoga 900-13ISK
# 1300       1318  Lenovo                       IdeaPad 100S-14IBR
# 1301       1319      HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus      X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 37              Notebook    17.3                 IPS Panel Full HD 1920x1080
# ...

# %%
df[data].sort_values(['Price_euros','TypeName'])
# Out:
#       laptop_ID  Company               Product     TypeName  Inches  \
# 290         295     Acer  Chromebook C910-C2ST     Notebook    15.6
# 1268       1286       HP      Stream 11-Y000na      Netbook    11.6
# 1282       1300       HP      Stream 11-Y000na      Netbook    11.6
# 1296       1314       HP      Stream 11-Y000na      Netbook    11.6
# 1272       1290   Lenovo    IdeaPad 100S-14IBR     Notebook    14.0
# ...         ...      ...                   ...          ...     ...
# 650         658     Asus            ROG G701VI       Gaming    17.3
# 491         498  Toshiba     Portege X30-D-10L    Ultrabook    13.3
# 1103       1118       HP              ZBook 17  Workstation    17.3
# 1017       1031   Lenovo          ThinkPad P70     Notebook    17.3
# 563         570   Lenovo          Thinkpad P71     Notebook    17.3
#
#                      ScreenResolution                                   Cpu  \
# ...

# %%
filterd = df.duplicated('Company',keep='first')

# %%
df[~filterd][['Company','Product','Inches','Price_euros']].sort_values('Price_euros')
# Out:
#        Company                        Product  Inches  Price_euros
# 30       Chuwi                  LapBook 15.6"    15.6       244.99
# 191       Vero  K147 (N3350/4GB/32GB/FHD/W10)    14.0       260.00
# 430    Samsung                   Chromebook 3    11.6       269.00
# 429   Mediacom                  FlexBook Edge    11.6       299.00
# 5         Acer                       Aspire 3    15.6       400.00
# 13        Dell                  Inspiron 3567    15.6       498.90
# 18      Lenovo              IdeaPad 320-15IKB    15.6       499.00
# 2           HP                         250 G6    15.6       575.00
# 143    Toshiba                  Satellite Pro    15.6       602.00
# 567    Fujitsu                  Lifebook A557    15.6       739.00
# 70   Microsoft                 Surface Laptop    13.5      1089.00
# 184     Xiaomi                    Mi Notebook    15.6      1199.00
# 0        Apple                    MacBook Pro    13.3      1339.69
# ...

# %%
df[~filterd][['Company','Product','Inches','Price_euros']].value_counts()
# Out:
# Company    Product                        Inches  Price_euros
# Acer       Aspire 3                       15.6    400.00         1
# Apple      MacBook Pro                    13.3    1339.69        1
# Asus       ZenBook UX430UN                14.0    1495.00        1
# Chuwi      LapBook 15.6"                  15.6    244.99         1
# Dell       Inspiron 3567                  15.6    498.90         1
# Fujitsu    Lifebook A557                  15.6    739.00         1
# Google     Pixelbook (Core                12.3    2199.00        1
# HP         250 G6                         15.6    575.00         1
# Huawei     MateBook X                     13.0    1349.00        1
# LG         Gram 15Z975                    15.6    2299.00        1
# Lenovo     IdeaPad 320-15IKB              15.6    499.00         1
# MSI        GS73VR 7RG                     17.3    2449.00        1
# Mediacom   FlexBook Edge                  11.6    299.00         1
# ...

# %%
test = df.duplicated('Price_euros', keep=False)

# %%
len(df[~test])
# Out:
# 580

# %%
dub = df.duplicated('Inches', keep='first')

# %%
len(df[~dub])
# Out:
# 18

# %%
df[['Company','Inches']]
# Out:
#      Company  Inches
# 0      Apple    13.3
# 1      Apple    13.3
# 2         HP    15.6
# 3      Apple    15.4
# 4      Apple    13.3
# ...      ...     ...
# 1298  Lenovo    14.0
# 1299  Lenovo    13.3
# 1300  Lenovo    14.0
# 1301      HP    15.6
# 1302    Asus    15.6
#
# [1303 rows x 2 columns]

# %%
df.drop_duplicates(['Company'])
# Out:
#      laptop_ID    Company                        Product            TypeName  \
# 0            1      Apple                    MacBook Pro           Ultrabook
# 2            3         HP                         250 G6            Notebook
# 5            6       Acer                       Aspire 3            Notebook
# 8            9       Asus                ZenBook UX430UN           Ultrabook
# 13          14       Dell                  Inspiron 3567            Notebook
# 18          19     Lenovo              IdeaPad 320-15IKB            Notebook
# 30          31      Chuwi                  LapBook 15.6"            Notebook
# 58          59        MSI                     GS73VR 7RG              Gaming
# 70          72  Microsoft                 Surface Laptop           Ultrabook
# 143        146    Toshiba                  Satellite Pro            Notebook
# 170        174     Huawei                     MateBook X           Ultrabook
# ...

# %%
len(df.drop_duplicates(['Product'])[['Company', 'OpSys']])
# Out:
# 618

# %%
pricing = df.sort_values(['Company', 'Price_euros'])
pricing.drop_duplicates(['Company'], keep='last')[['Company', 'Price_euros']]
# Out:
#         Company  Price_euros
# 1189       Acer      2599.00
# 17        Apple      2858.00
# 1066       Asus      3975.00
# 421       Chuwi       449.00
# 723        Dell      3659.40
# 623     Fujitsu       799.00
# 437      Google      2199.00
# 749          HP      4389.00
# 214      Huawei      1499.00
# 678          LG      2299.00
# 610      Lenovo      4899.00
# 177         MSI      2799.00
# 580    Mediacom       389.00
# 449   Microsoft      2589.00
# 196       Razer      6099.00
# 874     Samsung      1849.00
# 491     Toshiba      2799.00
# 191        Vero       260.00
# 514      Xiaomi      1399.95

# %%
dub = df.duplicated(['Company'], keep='first').value_counts()
# Out:
# True     1284
# False      19
# Name: count, dtype: int64

# %%
df[~dub][['Company']]
# Out:
#        Company
# 0        Apple
# 2           HP
# 5         Acer
# 8         Asus
# 13        Dell
# 18      Lenovo
# 30       Chuwi
# 58         MSI
# 70   Microsoft
# 143    Toshiba
# 170     Huawei
# 184     Xiaomi
# 191       Vero
# 196      Razer
# 429   Mediacom
# 430    Samsung
# 437     Google
# 567    Fujitsu
# 678         LG

# %%
pricing = df.sort_values(['Company', 'Price_euros'])
pricing.drop_duplicates(['Company'], keep='first')[['Company', 'Price_euros']]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
df = df.sort_values(['Company', 'Price_euros'])

# %%
# this in place work coz we are not filtering it or doing anything on it.
# we just put the data nothing else.
df.drop_duplicates(['Company'], keep='last', inplace=True, ignore_index=True)

# %%
df.drop_duplicates(['Company']).value_counts('Company')
# Out:
# Company
# Acer         1
# Apple        1
# Asus         1
# Chuwi        1
# Dell         1
# Fujitsu      1
# Google       1
# HP           1
# Huawei       1
# LG           1
# Lenovo       1
# MSI          1
# Mediacom     1
# Microsoft    1
# Razer        1
# Samsung      1
# Toshiba      1
# Vero         1
# Xiaomi       1
# Name: count, dtype: int64

# %%
dub = df.duplicated('Company')
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301     True
# 1302     True
# Length: 1303, dtype: bool

# %%
df[dub].value_counts('Company')
# Out:
# Company
# Dell         296
# Lenovo       296
# HP           273
# Asus         157
# Acer         102
# MSI           53
# Toshiba       47
# Apple         20
# Samsung        8
# Mediacom       6
# Razer          6
# Microsoft      5
# Vero           3
# Xiaomi         3
# Chuwi          2
# Fujitsu        2
# LG             2
# Google         2
# Huawei         1
# Name: count, dtype: int64

# %%
pricing
# Out:
#     laptop_ID    Company                        Product     TypeName  Inches  \
# 0        1207       Acer                Predator G9-793       Gaming    17.3
# 1          18      Apple                    MacBook Pro    Ultrabook    15.4
# 2        1081       Asus                     ROG G701VO       Gaming    17.3
# 3         428      Chuwi                   LapBook 12.3     Notebook    12.3
# 4         731       Dell                   Alienware 17       Gaming    17.3
# 5         630    Fujitsu                  LifeBook A557     Notebook    15.6
# 6         444     Google                Pixelbook (Core    Ultrabook    12.3
# 7         758         HP                       Zbook 17  Workstation    17.3
# 8         219     Huawei                     MateBook X    Ultrabook    13.0
# 9         686         LG                    Gram 15Z975    Ultrabook    15.6
# 10        617     Lenovo                   Thinkpad P51     Notebook    15.6
# ...

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df
# Out:
#     laptop_ID    Company                        Product     TypeName  Inches  \
# 0        1207       Acer                Predator G9-793       Gaming    17.3
# 1          18      Apple                    MacBook Pro    Ultrabook    15.4
# 2        1081       Asus                     ROG G701VO       Gaming    17.3
# 3         428      Chuwi                   LapBook 12.3     Notebook    12.3
# 4         731       Dell                   Alienware 17       Gaming    17.3
# 5         630    Fujitsu                  LifeBook A557     Notebook    15.6
# 6         444     Google                Pixelbook (Core    Ultrabook    12.3
# 7         758         HP                       Zbook 17  Workstation    17.3
# 8         219     Huawei                     MateBook X    Ultrabook    13.0
# 9         686         LG                    Gram 15Z975    Ultrabook    15.6
# 10        617     Lenovo                   Thinkpad P51     Notebook    15.6
# ...

# %%
df[['Company','Price_euros']]
# Out:
#       Company  Price_euros
# 0        Acer      2599.00
# 1       Apple      2858.00
# 2        Asus      3975.00
# 3       Chuwi       449.00
# 4        Dell      3659.40
# 5     Fujitsu       799.00
# 6      Google      2199.00
# 7          HP      4389.00
# 8      Huawei      1499.00
# 9          LG      2299.00
# 10     Lenovo      4899.00
# 11        MSI      2799.00
# 12   Mediacom       389.00
# 13  Microsoft      2589.00
# 14      Razer      6099.00
# 15    Samsung      1849.00
# 16    Toshiba      2799.00
# 17       Vero       260.00
# 18     Xiaomi      1399.95

# %%
df = pd.read_csv('laptop price.csv', encoding='latin')

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
inch = df.sort_values(['Company','Inches'])

# %%
inch.drop_duplicates(['Company'],keep='last')[['Company','Inches']]
# Out:
#         Company  Inches
# 1216       Acer    17.3
# 17        Apple    15.4
# 1256       Asus    17.3
# 483       Chuwi    15.6
# 1243       Dell    17.3
# 983     Fujitsu    15.6
# 762      Google    12.3
# 1136         HP    17.3
# 214      Huawei    13.0
# 905          LG    15.6
# 1217     Lenovo    17.3
# 177         MSI    18.4
# 718    Mediacom    14.0
# 670   Microsoft    13.5
# 830       Razer    17.3
# 593     Samsung    15.6
# 1042    Toshiba    15.6
# 1041       Vero    14.0
# 514      Xiaomi    15.6

# %%
inch.drop_duplicates(['Company'],keep='first')[['Company','Inches']]
# Out:
#         Company  Inches
# 319        Acer    11.6
# 1234      Apple    11.6
# 20         Asus    11.6
# 421       Chuwi    12.3
# 455        Dell    11.6
# 567     Fujitsu    15.6
# 437      Google    12.3
# 677          HP    11.6
# 170      Huawei    13.0
# 909          LG    14.0
# 50       Lenovo    10.1
# 785         MSI    14.0
# 429    Mediacom    11.6
# 70    Microsoft    13.5
# 816       Razer    12.5
# 430     Samsung    11.6
# 963     Toshiba    12.5
# 1120       Vero    13.3
# 192      Xiaomi    13.3
