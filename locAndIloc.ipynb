# %%
import pandas as pd

# %%
df = pd.read_csv('players_20.csv')

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
df.set_index('short_name', inplace=True)

# %%
df
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %%
df[["long_name"	,"age"	,"dob"	,"height_cm"	,"weight_kg"	,"nationality"	,"club"]]
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
df.loc['L. Messi']
# Out:
# sofifa_id                                                158023
# player_url    https://sofifa.com/player/158023/lionel-messi/...
# long_name                        Lionel Andrés Messi Cuccittini
# age                                                          32
# dob                                                  1987-06-24
#                                     ...
# lb                                                         63+2
# lcb                                                        52+2
# cb                                                         52+2
# rcb                                                        52+2
# rb                                                         63+2
# Name: L. Messi, Length: 103, dtype: object

# %%
str(df.loc['L. Messi','weight_kg'])
# Out:
# '72'

# %%
df.loc['L. Messi','nationality']
# Out:
# 'Argentina'

# %%
df.loc[:,'height_cm']
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Neymar Jr            175
# J. Oblak             188
# E. Hazard            175
#                     ...
# Shao Shuai           186
# Xiao Mingjie         177
# Zhang Wei            186
# Wang Haijian         185
# Pan Ximing           182
# Name: height_cm, Length: 18278, dtype: int64

# %%
df.loc['L. Messi',:]
# Out:
# sofifa_id                                                158023
# player_url    https://sofifa.com/player/158023/lionel-messi/...
# long_name                        Lionel Andrés Messi Cuccittini
# age                                                          32
# dob                                                  1987-06-24
#                                     ...
# lb                                                         63+2
# lcb                                                        52+2
# cb                                                         52+2
# rcb                                                        52+2
# rb                                                         63+2
# Name: L. Messi, Length: 103, dtype: object

# %%
# lets do it with list

# %%
df.loc[['L. Messi','Cristiano Ronaldo']]
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality          club  overall  \
# short_name
# L. Messi                 170         72   Argentina  FC Barcelona       94
# Cristiano Ronaldo        187         83    Portugal      Juventus       93
#
#                    ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb  \
# short_name         ...
# ...

# %%
df.loc[['L. Messi','Cristiano Ronaldo'], 'height_cm']
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Name: height_cm, dtype: int64

# %%
df.loc[['L. Messi','Cristiano Ronaldo'], :]
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality          club  overall  \
# short_name
# L. Messi                 170         72   Argentina  FC Barcelona       94
# Cristiano Ronaldo        187         83    Portugal      Juventus       93
#
#                    ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb  \
# short_name         ...
# ...

# %%
df.loc[['L. Messi','Cristiano Ronaldo'], ['height_cm','weight_kg','age']]
# Out:
#                    height_cm  weight_kg  age
# short_name
# L. Messi                 170         72   32
# Cristiano Ronaldo        187         83   34

# %%
df.loc[['L. Messi','Cristiano Ronaldo'], 'long_name':'club']
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality          club
# short_name
# L. Messi                 170         72   Argentina  FC Barcelona
# Cristiano Ronaldo        187         83    Portugal      Juventus

# %%
df.index[:10]
# Out:
# Index(['L. Messi', 'Cristiano Ronaldo', 'Neymar Jr', 'J. Oblak', 'E. Hazard',
#        'K. De Bruyne', 'M. ter Stegen', 'V. van Dijk', 'L. Modrić',
#        'M. Salah'],
#       dtype='object', name='short_name')

# %%
df.loc[df['height_cm']<180,'long_name':'club']
# Out:
#                                    long_name  age         dob  height_cm  \
# short_name
# L. Messi      Lionel Andrés Messi Cuccittini   32  1987-06-24        170
# Neymar Jr      Neymar da Silva Santos Junior   27  1992-02-05        175
# E. Hazard                        Eden Hazard   28  1991-01-07        175
# L. Modrić                        Luka Modrić   33  1985-09-09        172
# M. Salah                Mohamed  Salah Ghaly   27  1992-06-15        175
# ...                                      ...  ...         ...        ...
# Wang Peng                                 王鹏   21  1997-11-16        175
# J. Ryan                            Jack Ryan   19  2000-02-07        178
# M. Gallagher               Michael Gallagher   18  2000-07-09        178
# M. Sagaf                      Mohammed Sagaf   21  1997-11-12        177
# Xiao Mingjie                    Mingjie Xiao   22  1997-01-01        177
#
#               weight_kg          nationality                 club
# short_name
# ...

# %%
top10 = df.loc['L. Messi':'M. Salah', 'long_name':'club']

# %%
top10
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# K. De Bruyne                           Kevin De Bruyne   28  1991-06-28
# M. ter Stegen                    Marc-André ter Stegen   27  1992-04-30
# V. van Dijk                            Virgil van Dijk   27  1991-07-08
# L. Modrić                                  Luka Modrić   33  1985-09-09
# M. Salah                          Mohamed  Salah Ghaly   27  1992-06-15
#
#                    height_cm  weight_kg  nationality                 club
# short_name
# L. Messi                 170         72    Argentina         FC Barcelona
# ...

# %%
top10.loc[top10['height_cm']<180, 'long_name':'club']
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   32  1987-06-24        170
# Neymar Jr    Neymar da Silva Santos Junior   27  1992-02-05        175
# E. Hazard                      Eden Hazard   28  1991-01-07        175
# L. Modrić                      Luka Modrić   33  1985-09-09        172
# M. Salah              Mohamed  Salah Ghaly   27  1992-06-15        175
#
#             weight_kg nationality                 club
# short_name
# L. Messi           72   Argentina         FC Barcelona
# Neymar Jr          68      Brazil  Paris Saint-Germain
# E. Hazard          74     Belgium          Real Madrid
# L. Modrić          66     Croatia          Real Madrid
# M. Salah           71       Egypt            Liverpool

# %%
df[(df['nationality'] == 'Brazil') & (df['club'] == 'Real Madrid')]
# Out:
#               sofifa_id                                         player_url  \
# short_name
# Casemiro         200145  https://sofifa.com/player/200145/carlos-henriq...
# Marcelo          176676  https://sofifa.com/player/176676/marcelo-vieir...
# Éder Militão     240130  https://sofifa.com/player/240130/eder-gabriel-...
# Vinícius Jr.     238794  https://sofifa.com/player/238794/vinicius-jose...
# Rodrygo          243812  https://sofifa.com/player/243812/rodrygo-silva...
# Lucas Silva      209749  https://sofifa.com/player/209749/lucas-silva-b...
#
#                                       long_name  age         dob  height_cm  \
# short_name
# Casemiro      Carlos Henrique Venancio Casimiro   27  1992-02-23        185
# Marcelo          Marcelo Vieira da Silva Júnior   31  1988-05-12        174
# Éder Militão               Éder Gabriel Militão   21  1998-01-18        186
# Vinícius Jr.   Vinícius José de Oliveira Júnior   18  2000-07-12        176
# ...

# %% [markdown]
# # testing iloc

# %%
df.head()
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# ...

# %%
top10.iloc[0,3]
# Out:
# np.int64(170)

# %%
df.iloc[1,6]
# Out:
# np.int64(83)

# %%
df.iloc[0:11,3:5]
# Out:
#                    age         dob
# short_name
# L. Messi            32  1987-06-24
# Cristiano Ronaldo   34  1985-02-05
# Neymar Jr           27  1992-02-05
# J. Oblak            26  1993-01-07
# E. Hazard           28  1991-01-07
# K. De Bruyne        28  1991-06-28
# M. ter Stegen       27  1992-04-30
# V. van Dijk         27  1991-07-08
# L. Modrić           33  1985-09-09
# M. Salah            27  1992-06-15
# K. Mbappé           20  1998-12-20

# %%
df.iloc[0,:]
# Out:
# sofifa_id                                                158023
# player_url    https://sofifa.com/player/158023/lionel-messi/...
# long_name                        Lionel Andrés Messi Cuccittini
# age                                                          32
# dob                                                  1987-06-24
#                                     ...
# lb                                                         63+2
# lcb                                                        52+2
# cb                                                         52+2
# rcb                                                        52+2
# rb                                                         63+2
# Name: L. Messi, Length: 103, dtype: object
