# %% [markdown]
# # sort Index and set Index

# %%
import pandas as pd

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import numpy as np
import random

# %%
newIndex = np.arange(0,1000)

# %%
random.shuffle(newIndex)

# %%
newIndex
# Out:
# array([911, 860, 691, 952, 727, 869, 937,  99, 235, 315, 759, 309,  56,
#        262, 242, 344,  52, 351, 139, 709, 180,  35, 768, 862,  89, 265,
#        661, 387, 830, 263, 778, 272, 672,  70, 636, 702, 376,  83, 516,
#        777, 308, 654, 349, 712, 530, 554, 570, 844, 781, 491, 721, 732,
#        233, 559, 176, 191, 903, 467, 978, 314,  60, 643, 812, 279, 149,
#        373,  81, 505, 122, 470,  78, 394, 761, 710, 316, 880, 278, 420,
#        433, 659, 599, 723, 674,  38, 125, 271, 494, 220, 739, 303, 602,
#        361, 414, 179,  90, 509, 589, 385, 345,  79, 929, 934,  62, 328,
#        365, 370, 591, 953,  57, 422, 246, 902, 341, 402,  76, 480, 447,
#        938, 568, 942, 165,  53, 187,  59, 637, 204, 772, 720, 557, 632,
#         47, 221, 141, 852, 398, 787, 625,  85, 993, 310, 718, 135, 582,
#        155, 534, 109, 533, 724, 159, 498, 842, 998, 313, 190, 388, 445,
#        441, 524, 538, 212, 614, 797, 111, 536, 484, 550, 535, 142,   3,
# ...

# %%
df['new index'] = newIndex

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # setIndex

# %%
df.set_index('new index', inplace=True)

# %%
df
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new index
# 911        female        group B           bachelor's degree      standard
# 860        female        group C                some college      standard
# 691        female        group B             master's degree      standard
# 952          male        group A          associate's degree  free/reduced
# 727          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 537        female        group E             master's degree      standard
# 857          male        group C                 high school  free/reduced
# 48         female        group C                 high school  free/reduced
# 197        female        group D                some college      standard
# 944        female        group D                some college  free/reduced
#
# ...

# %%
df.sort_index(ascending=False, inplace=True)

# %%
df
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new index
# 999        female        group C          associate's degree      standard
# 998          male        group A           bachelor's degree      standard
# 997          male        group D          associate's degree  free/reduced
# 996        female        group C             master's degree      standard
# 995        female        group D                some college      standard
# ...           ...            ...                         ...           ...
# 4            male        group D            some high school      standard
# 3          female        group B                 high school      standard
# 2            male        group D                some college      standard
# 1            male        group C          associate's degree  free/reduced
# 0            male        group D          associate's degree  free/reduced
#
# ...

# %% [markdown]
# # rename a column

# %%
df.rename(columns={'gender':'Gender'}, inplace=True)

# %%
df
# Out:
#            Gender race/ethnicity parental level of education         lunch  \
# new index
# 999        female        group C          associate's degree      standard
# 998          male        group A           bachelor's degree      standard
# 997          male        group D          associate's degree  free/reduced
# 996        female        group C             master's degree      standard
# 995        female        group D                some college      standard
# ...           ...            ...                         ...           ...
# 4            male        group D            some high school      standard
# 3          female        group B                 high school      standard
# 2            male        group D                some college      standard
# 1            male        group C          associate's degree  free/reduced
# 0            male        group D          associate's degree  free/reduced
#
# ...

# %%
df.rename(index={0:'a',1:'b',2:'c'}, inplace=True)

# %%
df
# Out:
#            Gender race/ethnicity parental level of education         lunch  \
# new index
# 999        female        group C          associate's degree      standard
# 998          male        group A           bachelor's degree      standard
# 997          male        group D          associate's degree  free/reduced
# 996        female        group C             master's degree      standard
# 995        female        group D                some college      standard
# ...           ...            ...                         ...           ...
# 4            male        group D            some high school      standard
# 3          female        group B                 high school      standard
# c            male        group D                some college      standard
# b            male        group C          associate's degree  free/reduced
# a            male        group D          associate's degree  free/reduced
#
# ...

# %%
df.tail(3)
# Out:
#           Gender race/ethnicity parental level of education         lunch  \
# new index
# c           male        group D                some college      standard
# b           male        group C          associate's degree  free/reduced
# a           male        group D          associate's degree  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new index
# c                       completed          85             81             85
# b                            none          77             67             64
# a                            none          75             66             73
